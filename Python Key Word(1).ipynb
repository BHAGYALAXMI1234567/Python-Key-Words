# %% [raw]
# Q1 )Explain the significance of Python keywords and provide examples of five keywords
#
# Ans)Keywords are predefined reserved word in python which has some special meaning that python interpreter can understand and does a specific task.These keywords helps us to perform specific task without any difficulty. The keyword cannot be used as an identifier, function, or variable name. For eg:- print,True, if, continue, break, etc.

# %% [raw]
# Q2 )Describe the rules for defining identifiers in Python and provide an example.
#
# Ans)The rules for defining identifiers are:
#
#
# •)Identifier names in Python can contain numbers (0-9), uppercase letters (A-Z), lowercase letters (a-z), and underscore (_).
#
# eg: abd23 #valid way of writing identifier
#
#
# •)The name should always start with a non-numeric character.
#
# eg:
#
# ABC #valid way of defining identifier
#
# abc #valid way of defining identifier
#
# AbC #valid way of defining identifier
#
# 1bc #invalid way of defining identifier
#
#
# •)An identifier name should not contain numeric characters only.
#
# eg:
#
# 123 #invalid way of defining identifier
#
#
# •)Identifier names in Python are case-sensitive like most other languages.
#
# eg:
#
# ‘Amlan’ is different from ‘AMLAN’
#
#
# •)We can begin identifiers with an underscore.
#
# eg:
#
# _ #valid way of defining identifier
#
# _ab #valid way of defining identifier
#
#
# •)Identifiers should not have the same name as keywords.
#
# eg:
#
# print #invalid way of defining identifier

# %% [raw]
# Q3 )What are comments in Python, and why are they useful? Provide an example
#
# Ans) Comments are line written within python code to make the code more readable by explaining the purpose of writing it. They are written in a way so that they could remain unidentified by the python interpreter which would otherwise throw an error. It is of two types:
#
# a) Single line comment: It consist of a single line and start with #.
#
# eg:
#
# # This is an example of single line comment.
#
# b) Multiline comment/ docstring: It consist of more than one line. They are used to document a Python module, class, function or method, so programmers can understand what it does without having to read the details of the implementation. They starts and ends with “““.
#
# eg:
#
# ”“”
#
# This is an example of docstring
#
# Given to answer this particular question Of the assignment
#
# ““”

# %% [raw]
# Q4 )Why is proper indentation important in Python?
#
# Ans )A proper indentation is important in python due to the following reason:
#
# •)Improved Readability: Indentation makes the code more readable by clearly indicating which statements belong to which block of code. This makes it easier for other developers to understand your code and makes it more maintainable.
#
# •)Consistency: By requiring consistent indentation levels, Python ensures that the code follows a consistent style, making it easier to read and understand.
#
# •)Reduced Syntax: Python’s use of indentation reduces the amount of syntax required to define blocks of code. This makes Python code shorter and easier to read than code written in other languages.
#
# •)Reduced Errors: By requiring consistent indentation levels, Python reduces the likelihood of indentation-related errors that can occur in other languages. This improves code quality and reduces the time required for debugging.
#
# •)Increased Efficiency: Python’s use of indentation simplifies the coding process and allows developers to write code faster and with fewer errors.

# %% [raw]
# Q5 )What happens if indentation is incorrect in Python?
#
# Ans)Incorrect indentation can result in syntax errors and impact the logical structure of your code. Python relies on consistent indentation to identify code blocks, so improper indentation may lead to unexpected behavior or make your code difficult to understand and could also interfer with our decision when to implement a block of code on fulfilment of a specific condition. Therefore it’s essential to pay attention to indentation to ensure the proper execution of your Python programs.

# %% [raw]
# Q6)Differentiate between expression and statement in Python with examples.
#
# Ans)
#
# EXPRESSION:
#
# •)An Expression is a sequence or combination of values, variables, operators and function calls that always produces or returns a result value.
#
# •)Each and every line of code that we write in python could not be called as expression.
#
# •) eg:
#
# x = 5, y = 3, z = x + y
#
# In the above example x, y and z are variables, 5 and 3 are values, = and + are operators. So, the first combination x = 5 is an expression, the second combination y = 3 is an another expression and at last, z = x + y is also an expression.
#
# STATEMENT:
#
# •)Statement is the smallest executable unit of code that has an effect, like creating a variable or displaying a value. Sentence may or may not return a value
#
# •)Each and every line of code that we write in python is called a statement, because, all the lines are executable by the interpreter.
#
# •)eg:
#
# x=3
#
# if x>2 and x<10
#
#     x+=1
#
#     print(x)
#
# else
#
#   break
#
#
# The first line is an assignment statement that gives a value to x. The second line is a if statement that execute a block of code based on a condition. Similarly there is else statement which has break as it sub code which is note an expression but is a statement. When you type a statement then the interpreter executes it, which means that it does whatever the statement says. Some other kinds of statements in Python are– if statement, else statement, while statement, for statement, import statement, etc.
